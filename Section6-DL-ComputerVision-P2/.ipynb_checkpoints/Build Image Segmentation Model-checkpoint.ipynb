# %%
from IPython.display import Image, display
display(Image("./images/PallenceAI-Final.png", width=800))

# %% [markdown]
# # Build a Segmentation Model with CNN's on Oxford Pets-III dataset

# %%
display(Image("./images/pet_annotations2.jpg" , width=400))

# %% [markdown]
# ### Import needed libraries

# %%
#### IF you are using Google colab only then please do the following to make it easy to work in colab. 
# Uncomment and run cells in colab

# 1. Mount ur google drive where the course folder is downloaded.
# from google.colab import drive
# drive.mount('/content/drive')

# 2. Set the path to the course directory
# import os
# os.chdir('/content/drive/My Drive/Course-1-Deep-Learning-Mastery-Build-Your-AI-Foundation-main/Section4')
# print("Current Directory:", os.getcwd())

# 3. install the following libraries. u can install any other library also with !pip install "library"
# !pip install tensorflow numpy pandas matplotlib

# %%
#Basic Python packages for data wrangling
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import random

#Tensorflow & Keras related packages
import tensorflow as tf
from tensorflow import keras
from keras import layers
from tensorflow.keras.utils import load_img, img_to_array

from utils import plot_history

# %%
random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# ### Download Oxford Pets III Dataset Preloaded in Keras

# %% [markdown]
# https://www.robots.ox.ac.uk/~vgg/data/pets/
#
# **images:** http://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz
#
# **segmentation masks:** http://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz

# %% [markdown]
# ### Load & Understand the Data

# %%
# Once you have downloaded the data
# Create paths to where images and the corresponding annotations are located
base_dir = Path("oxford-pets_data")

# Directory where images are stored
images_dir = base_dir / "images"

# Directory where segmentation masks or labels are stored
masks_dir = base_dir / "annotations" / "trimaps"

# %%
print (images_dir)
# Out:
# oxford-pets_data\images

# %%
print (masks_dir)
# Out:
# oxford-pets_data\annotations\trimaps

# %% [markdown]
# **First, load the paths of each file**

# %%
images_paths = sorted([img_path for img_path in images_dir.iterdir() if img_path.suffix == ".jpg"])
masks_paths = sorted([mask_path for mask_path in masks_dir.iterdir() if not mask_path.name.startswith(".")])

# %%
# # First, load the paths of each file
# images_paths = [img_path for img_path in images_dir.iterdir() if img_path.suffix == ".jpg"]
# masks_paths = [mask_path for mask_path in masks_dir.iterdir() if not mask_path.name.startswith(".")]

# %%
images_paths[0]
# Out:
# WindowsPath('oxford-pets_data/images/Abyssinian_1.jpg')

# %%
masks_paths[0]
# Out:
# WindowsPath('oxford-pets_data/annotations/trimaps/Abyssinian_1.png')

# %%
random.Random(42).shuffle(images_paths)
random.Random(42).shuffle(masks_paths)

# %%
images_paths[0]
# Out:
# WindowsPath('oxford-pets_data/images/shiba_inu_65.jpg')

# %%
masks_paths[0]
# Out:
# WindowsPath('oxford-pets_data/annotations/trimaps/shiba_inu_65.png')

# %% [markdown]
# **Load the images & corresponding mask labels and preproces them**

# %%
images = [img_to_array(load_img(path)) for path in images_paths[0:2]]

# %%
images[0].shape
# Out:
# (500, 375, 3)

# %%
len(images_paths)
# Out:
# 7390

# %%
# Lets resize images and store them 
images = [img_to_array(load_img(path, target_size = (200,200))) for path in images_paths]

# %%
images[0].shape
# Out:
# (200, 200, 3)

# %%
# For mask labels, these are also of 2D image shape, but the pixel values for these images are labels

# 1 (foreground)
# 2 (background)
# 3 (contour)

# So we convert these mask labels into integers and substract by 1, to get values of 0, 1, 2
# also we choose grayscale when we load the mask image to represent a single color channel


mask_labels = [img_to_array(load_img(path, target_size = (200,200),color_mode="grayscale"))
               .astype('uint8')-1
                for path in masks_paths]

# %%
mask_labels[0].shape
# Out:
# (200, 200, 1)

# %%
# Now lets convert the list of images & labels into numpy arrays

images = np.stack(images)
mask_labels = np.stack(mask_labels)

print (images.shape)
print (mask_labels.shape)
# Out:
# (7390, 200, 200, 3)
# (7390, 200, 200, 1)

# %%
# so we have around 7390 images & corresponding masks which are greyscale images

# %% [markdown]
# **Lets look at a single image**

# %%
# data type of the values inside the images array
images.dtype
# Out:
# dtype('float32')

# %%
# Lets visualize a sample image

# matplotlib expects image data to be in the range [0, 1] for floating-point arrays 
#...and [0, 255] for integer arrays. 

plt.imshow(images[0]/255.0)
plt.show()

# %% [markdown]
# **Now lets look at the corresponding mask labels**

# %%
# mask_labels are also images corresponding to acutal pets images 
#...but with values representing the mask labels

mask_labels.shape
# Out:
# (7390, 200, 200, 1)

# %%
mask_labels.dtype
# Out:
# dtype('uint8')

# %%
np.unique(mask_labels[0]) # These are the unique values in the mask_labels images. 0, 1, 2
# Out:
# array([0, 1, 2], dtype=uint8)

# %%
# Lets visualize the mask label image
plt.imshow(mask_labels[0], cmap = "gray")

# cmap='gray': This sets the colormap to grayscale, 
# ensuring that the image is displayed using shades of gray rather than the default colormap.

plt.show()

# %% [markdown]
# ### Split data into Train, Valid

# %%
len(images)
# Out:
# 7390

# %%
# We will use around 1000 samples for validation data

train_images = images[:6390]
train_masks = mask_labels[:6390]

val_images = images[6390:]
val_masks = mask_labels[6390:]

# %%
train_images.shape
# Out:
# (6390, 200, 200, 3)

# %%
val_images.shape
# Out:
# (1000, 200, 200, 3)

# %% [markdown]
# ### Build the model architecture

# %%
# Unlike classification tasks, for segmentation as u see below we will use strided convolutions
# Strided convolutions are better at retaining local spatial information compared to maxpooling layers.

def segmentation_model():
    
    # Define input
    inputs = keras.Input(shape=(200,200,3))
    
    # Rescaling layer
    x = layers.Rescaling(1.0/255)(inputs)
    
    # First half of the architecture focuses on encoding images into smaller feature maps
    x = layers.Conv2D(64, 3, strides=2, activation="relu", padding="same")(x)
    x = layers.Conv2D(64, 3, activation="relu", padding="same")(x)
    x = layers.Conv2D(128, 3, strides=2, activation="relu", padding="same")(x)
    x = layers.Conv2D(128, 3, activation="relu", padding="same")(x)
    x = layers.Conv2D(256, 3, strides=2, padding="same", activation="relu")(x)
    x = layers.Conv2D(256, 3, activation="relu", padding="same")(x)

    # 2nd half of the architecture focuses on upsampling the image back to be of same shape as our mask _label images
    x = layers.Conv2DTranspose(256, 3, activation="relu", padding="same")(x)
    x = layers.Conv2DTranspose(256, 3, activation="relu", padding="same", strides=2)(x)
    x = layers.Conv2DTranspose(128, 3, activation="relu", padding="same")(x)
    x = layers.Conv2DTranspose(128, 3, activation="relu", padding="same", strides=2)(x)
    x = layers.Conv2DTranspose(64, 3, activation="relu", padding="same")(x)
    x = layers.Conv2DTranspose(64, 3, activation="relu", padding="same", strides=2)(x)

    outputs = layers.Conv2D(3, 3, activation="softmax", padding="same")(x)

    model = keras.Model(inputs, outputs)
    return model

# %%
model = segmentation_model()
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 200, 200, 3)]     0
#
#  rescaling (Rescaling)       (None, 200, 200, 3)       0
#
#  conv2d (Conv2D)             (None, 100, 100, 64)      1792
#
#  conv2d_1 (Conv2D)           (None, 100, 100, 64)      36928
#
#  conv2d_2 (Conv2D)           (None, 50, 50, 128)       73856
#
#  conv2d_3 (Conv2D)           (None, 50, 50, 128)       147584
#
#  conv2d_4 (Conv2D)           (None, 25, 25, 256)       295168
#
#  conv2d_5 (Conv2D)           (None, 25, 25, 256)       590080
#
#  conv2d_transpose (Conv2DTra  (None, 25, 25, 256)      590080
#  nspose)
#
#  conv2d_transpose_1 (Conv2DT  (None, 50, 50, 256)      590080
#  ranspose)
#
#  conv2d_transpose_2 (Conv2DT  (None, 50, 50, 128)      295040
#  ranspose)
#
#  conv2d_transpose_3 (Conv2DT  (None, 100, 100, 128)    147584
#  ranspose)
#
#  conv2d_transpose_4 (Conv2DT  (None, 100, 100, 64)     73792
#  ranspose)
#
#  conv2d_transpose_5 (Conv2DT  (None, 200, 200, 64)     36928
#  ranspose)
#
#  conv2d_6 (Conv2D)           (None, 200, 200, 3)       1731
#
# =================================================================
# Total params: 2,880,643
# Trainable params: 2,880,643
# Non-trainable params: 0
# _________________________________________________________________

# %%
mask_labels.shape #actual Y mask labels.
# Out:
# (7390, 200, 200, 1)

# %% [markdown]
# ## Compile the Model

# %%
# Compile the model
model.compile(optimizer="rmsprop", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# %%
# Callbacks

# model_checkpoint = keras.callbacks.ModelCheckpoint("oxford_segmentation.keras", 
#                                     monitor="val_loss",
#                                     save_best_only=True)

# early_stop = keras.callbacks.EarlyStopping(monitor="val_loss", 
#                                            patience=3, 
#                                            restore_best_weights=True)

# callbacks = [early_stop]

# %%
history = model.fit(train_images, train_masks,
                    epochs=50,
                    batch_size=16,
                    validation_data=(val_images, val_masks))
# Out:
# Epoch 1/50
# 400/400 [==============================] - 54s 105ms/step - loss: 1.5339 - accuracy: 0.6272 - val_loss: 0.7998 - val_accuracy: 0.6816
# Epoch 2/50
# 400/400 [==============================] - 39s 98ms/step - loss: 0.7370 - accuracy: 0.7002 - val_loss: 0.6448 - val_accuracy: 0.7352
# Epoch 3/50
# 400/400 [==============================] - 39s 98ms/step - loss: 0.6364 - accuracy: 0.7414 - val_loss: 0.6106 - val_accuracy: 0.7529
# Epoch 4/50
# 400/400 [==============================] - 40s 99ms/step - loss: 0.5716 - accuracy: 0.7715 - val_loss: 0.7279 - val_accuracy: 0.6984
# Epoch 5/50
# 400/400 [==============================] - 39s 98ms/step - loss: 0.5283 - accuracy: 0.7918 - val_loss: 0.5161 - val_accuracy: 0.8007
# Epoch 6/50
# 400/400 [==============================] - 39s 98ms/step - loss: 0.4964 - accuracy: 0.8057 - val_loss: 0.6835 - val_accuracy: 0.7456
# Epoch 7/50
# 400/400 [==============================] - 39s 98ms/step - loss: 0.4666 - accuracy: 0.8181 - val_loss: 0.4729 - val_accuracy: 0.8171
# Epoch 8/50
# 400/400 [==============================] - 39s 98ms/step - loss: 0.4399 - accuracy: 0.8290 - val_loss: 0.4779 - val_accuracy: 0.8171
# Epoch 9/50
# 400/400 [==============================] - 39s 98ms/step - loss: 0.4225 - accuracy: 0.8357 - val_loss: 0.4349 - val_accuracy: 0.8351
# Epoch 10/50
# 400/400 [==============================] - 40s 99ms/step - loss: 0.4042 - accuracy: 0.8435 - val_loss: 0.4114 - val_accuracy: 0.8431
# Epoch 11/50
# 400/400 [==============================] - 39s 98ms/step - loss: 0.3878 - accuracy: 0.8503 - val_loss: 0.4154 - val_accuracy: 0.8490
# Epoch 12/50
# 400/400 [==============================] - 39s 98ms/step - loss: 0.3768 - accuracy: 0.8545 - val_loss: 0.4527 - val_accuracy: 0.8308
# Epoch 13/50
# 400/400 [==============================] - 39s 98ms/step - loss: 0.3615 - accuracy: 0.8609 - val_loss: 0.3958 - val_accuracy: 0.8508
# Epoch 14/50
# 400/400 [==============================] - 40s 99ms/step - loss: 0.3546 - accuracy: 0.8644 - val_loss: 0.4227 - val_accuracy: 0.8459
# Epoch 15/50
# 400/400 [==============================] - 39s 98ms/step - loss: 0.3376 - accuracy: 0.8700 - val_loss: 0.4012 - val_accuracy: 0.8557
# Epoch 16/50
# 400/400 [==============================] - 40s 100ms/step - loss: 0.3293 - accuracy: 0.8732 - val_loss: 0.4471 - val_accuracy: 0.8481
# Epoch 17/50
# 400/400 [==============================] - 40s 101ms/step - loss: 0.3186 - accuracy: 0.8775 - val_loss: 0.4079 - val_accuracy: 0.8587
# Epoch 18/50
# 400/400 [==============================] - 40s 100ms/step - loss: 0.3075 - accuracy: 0.8817 - val_loss: 0.4403 - val_accuracy: 0.8316
# Epoch 19/50
# 400/400 [==============================] - 40s 100ms/step - loss: 0.2953 - accuracy: 0.8861 - val_loss: 0.4073 - val_accuracy: 0.8457
# Epoch 20/50
# 400/400 [==============================] - 40s 100ms/step - loss: 0.2853 - accuracy: 0.8901 - val_loss: 0.3802 - val_accuracy: 0.8648
# Epoch 21/50
# 400/400 [==============================] - 40s 99ms/step - loss: 0.2753 - accuracy: 0.8940 - val_loss: 0.4237 - val_accuracy: 0.8437
# Epoch 22/50
# 400/400 [==============================] - 42s 104ms/step - loss: 0.2652 - accuracy: 0.8975 - val_loss: 0.3976 - val_accuracy: 0.8647
# Epoch 23/50
# 400/400 [==============================] - 41s 102ms/step - loss: 0.2544 - accuracy: 0.9018 - val_loss: 0.4164 - val_accuracy: 0.8606
# Epoch 24/50
# 400/400 [==============================] - 40s 101ms/step - loss: 0.2464 - accuracy: 0.9051 - val_loss: 0.4168 - val_accuracy: 0.8643
# Epoch 25/50
# 400/400 [==============================] - 39s 99ms/step - loss: 0.2404 - accuracy: 0.9070 - val_loss: 0.4039 - val_accuracy: 0.8691
# Epoch 26/50
# 400/400 [==============================] - 40s 99ms/step - loss: 0.2284 - accuracy: 0.9114 - val_loss: 0.4179 - val_accuracy: 0.8691
# Epoch 27/50
# 400/400 [==============================] - 40s 99ms/step - loss: 0.2210 - accuracy: 0.9142 - val_loss: 0.4737 - val_accuracy: 0.8658
# Epoch 28/50
# 400/400 [==============================] - 40s 100ms/step - loss: 0.2170 - accuracy: 0.9161 - val_loss: 0.4555 - val_accuracy: 0.8577
# Epoch 29/50
# 400/400 [==============================] - 40s 99ms/step - loss: 0.2093 - accuracy: 0.9189 - val_loss: 0.5132 - val_accuracy: 0.8648
# Epoch 30/50
# 400/400 [==============================] - 40s 99ms/step - loss: 0.2049 - accuracy: 0.9209 - val_loss: 0.4784 - val_accuracy: 0.8467
# Epoch 31/50
# 400/400 [==============================] - 40s 99ms/step - loss: 0.1990 - accuracy: 0.9232 - val_loss: 0.5026 - val_accuracy: 0.8495
# Epoch 32/50
# 400/400 [==============================] - 39s 98ms/step - loss: 0.1925 - accuracy: 0.9252 - val_loss: 0.5310 - val_accuracy: 0.8322
# Epoch 33/50
# 400/400 [==============================] - 39s 98ms/step - loss: 0.1871 - accuracy: 0.9271 - val_loss: 0.4837 - val_accuracy: 0.8628
# Epoch 34/50
# 400/400 [==============================] - 40s 99ms/step - loss: 0.1799 - accuracy: 0.9296 - val_loss: 0.4329 - val_accuracy: 0.8684
# Epoch 35/50
# 400/400 [==============================] - 39s 98ms/step - loss: 0.1753 - accuracy: 0.9313 - val_loss: 0.4513 - val_accuracy: 0.8655
# Epoch 36/50
# 400/400 [==============================] - 40s 99ms/step - loss: 0.1735 - accuracy: 0.9325 - val_loss: 0.5190 - val_accuracy: 0.8558
# Epoch 37/50
# 400/400 [==============================] - 42s 105ms/step - loss: 0.1704 - accuracy: 0.9335 - val_loss: 0.5450 - val_accuracy: 0.8583
# Epoch 38/50
# 400/400 [==============================] - 40s 99ms/step - loss: 0.1681 - accuracy: 0.9352 - val_loss: 0.4997 - val_accuracy: 0.8544
# Epoch 39/50
# 400/400 [==============================] - 40s 99ms/step - loss: 0.1647 - accuracy: 0.9356 - val_loss: 0.5867 - val_accuracy: 0.8672
# Epoch 40/50
# 400/400 [==============================] - 39s 98ms/step - loss: 0.1586 - accuracy: 0.9378 - val_loss: 0.5671 - val_accuracy: 0.8625
# Epoch 41/50
# 400/400 [==============================] - 39s 98ms/step - loss: 0.1670 - accuracy: 0.9389 - val_loss: 0.6778 - val_accuracy: 0.8002
# Epoch 42/50
# 400/400 [==============================] - 39s 97ms/step - loss: 0.1565 - accuracy: 0.9389 - val_loss: 0.5299 - val_accuracy: 0.8680
# Epoch 43/50
# 400/400 [==============================] - 39s 98ms/step - loss: 0.1474 - accuracy: 0.9420 - val_loss: 0.5780 - val_accuracy: 0.8433
# Epoch 44/50
# 400/400 [==============================] - 39s 98ms/step - loss: 0.1507 - accuracy: 0.9409 - val_loss: 0.7546 - val_accuracy: 0.8643
# Epoch 45/50
# 400/400 [==============================] - 39s 97ms/step - loss: 0.1485 - accuracy: 0.9419 - val_loss: 0.8694 - val_accuracy: 0.8636
# Epoch 46/50
# 400/400 [==============================] - 39s 97ms/step - loss: 0.3443 - accuracy: 0.9394 - val_loss: 0.5426 - val_accuracy: 0.8601
# Epoch 47/50
# 400/400 [==============================] - 39s 99ms/step - loss: 0.1464 - accuracy: 0.9429 - val_loss: 0.6005 - val_accuracy: 0.8664
# Epoch 48/50
# 400/400 [==============================] - 39s 98ms/step - loss: 0.1424 - accuracy: 0.9443 - val_loss: 0.7643 - val_accuracy: 0.8659
# Epoch 49/50
# 400/400 [==============================] - 39s 99ms/step - loss: 0.1380 - accuracy: 0.9456 - val_loss: 0.6130 - val_accuracy: 0.8407
# Epoch 50/50
# 400/400 [==============================] - 39s 98ms/step - loss: 0.1362 - accuracy: 0.9463 - val_loss: 0.6502 - val_accuracy: 0.8660

# %% [markdown]
# ### Plotting the loss & Accuracy curves

# %%
plot_history(history)
